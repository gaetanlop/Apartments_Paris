# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('House_price_cleaned.csv')

# %%
df.shape
# Out:
# (2557, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2557 entries, 0 to 2556
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Superficie          2557 non-null   object
#  1   Rooms               2557 non-null   object
#  2   Bedrooms            2557 non-null   object
#  3   Price               2557 non-null   object
#  4   Location            2557 non-null   object
#  5   description         2557 non-null   object
#  6   Loc_Paris           2557 non-null   int64
#  7   m2                  2557 non-null   int64
#  8   building_floor      2557 non-null   int64
#  9   apartment_floor     2557 non-null   int64
#  10  nb_bath             2557 non-null   int64
#  11  Cellar              2557 non-null   int64
#  12  balc_patio          2557 non-null   object
#  13  Heating             2557 non-null   object
#  14  Renovated           2557 non-null   int64
# ...

# %%
df.describe()
# Out:
#          Loc_Paris           m2  building_floor  apartment_floor      nb_bath  \
# count  2557.000000  2557.000000     2557.000000      2557.000000  2557.000000
# mean     12.626124    74.482597        6.705905         3.673445     0.675401
# std       5.271301    57.248089        3.586994         2.815973     0.748128
# min       1.000000     4.000000        1.000000         1.000000     0.000000
# 25%       8.000000    36.000000        5.000000         2.000000     0.000000
# 50%      14.000000    60.000000        6.000000         3.000000     1.000000
# 75%      17.000000    94.000000        7.000000         5.000000     1.000000
# max      20.000000   855.000000       33.000000        32.000000    10.000000
#
#             Cellar    Renovated      Parking  Heating_Central  \
# count  2557.000000  2557.000000  2557.000000      2557.000000
# mean      0.583887     0.082127     0.124364         0.232695
# std       0.493009     0.274613     0.330061         0.422632
# ...

# %% [markdown]
# Outliers detected. We will explore them later after separating the dataframe into numerical and catgeorical features and then plotting the distribution of the numerical features.

# %%
df.columns
# Out:
# Index(['Superficie', 'Rooms', 'Bedrooms', 'Price', 'Location', 'description',
#        'Loc_Paris', 'm2', 'building_floor', 'apartment_floor', 'nb_bath',
#        'Cellar', 'balc_patio', 'Heating', 'Renovated', 'Parking',
#        'Heating_Central', 'Heating_Individual', 'Price_int', 'Last_floor'],
#       dtype='object')

# %%
#numerical variables
num=['m2','Price_int']

#categorical variables
cat=['Rooms', 'Bedrooms','building_floor', 'apartment_floor', 'nb_bath','balc_patio','Loc_Paris','Cellar','Renovated', 'Parking', 'Heating_Central',
       'Heating_Individual','Last_floor']

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Exploring numerical features and detecting and removing outiliers

# %%
for i in num:
    df[i].hist()
    plt.title(f'{i} distribution')
    plt.show()

# %% [markdown]
# m2, Price_int are not normally distributed. We will need to normalize to use some regression techniques. May be we can use the log transformation.

# %% [markdown]
# #### Outliers Detection and Removal

# %% [markdown]
# First of all we will have a look at the column m2 which represents the number of square feet of the apartment.

# %%
df.boxplot(column='m2')

# %% [markdown]
# It seems that there are a lot of outliers. Let's check them.

# %%
df[df.m2>175]
# Out:
#      Superficie  Rooms Bedrooms        Price  \
# 10        189m²   6 p.     4 p.   2 490 000
# 63        202m²   7 p.     4 p.   3 300 000
# 73        182m²   6 p.     4 p.   2 450 000
# 74        187m²   6 p.     3 p.   2 475 000
# 85        201m²   6 p.     3 p.   3 150 000
# 88        193m²   6 p.     3 p.   2 530 000
# 91        288m²   7 p.     4 p.   3 150 000
# 93        218m²   6 p.     4 p.   2 650 000
# 98        233m²   3 p.     2 p.     835 000
# 104       229m²   4 p.     2 p.   1 455 000
# 108       340m²   4 p.     2 p.   2 050 000
# 109       233m²   7 p.     5 p.   5 270 000
# 142       276m²   6 p.     4 p.   3 500 000
# 151       208m²   7 p.     5 p.   1 995 000
# 163       189m²   6 p.     4 p.   2 410 000
# 203       386m²   4 p.     2 p.   2 060 000
# 232       271m²   7 p.     3 p.   6 300 000
# 233       245m²   7 p.     4 p.   5 950 000
# 234       206m²   7 p.     4 p.   3 500 000
# 271       213m²   6 p.     4 p.   2 900 000
# ...

# %% [markdown]
# These apartments are real, but it is very rare to find apartments of more than 175 m² in Paris. We should consider them as outliers and remove them.

# %%
df=df[~(df.m2>175)]

# %% [markdown]
# It seems that there are some apartments that are less than 10 meters. Let us check them.

# %%
pd.set_option('display.max_rows', None)
df[df.m2<10]
# Out:
#      Superficie Rooms Bedrooms       Price  \
# 156         9m²  1 p.     0 p.    117 500
# 228         8m²  1 p.     0 p.     86 000
# 291         9m²  1 p.     0 p.    110 000
# 358         7m²  1 p.     0 p.    105 000
# 383         8m²  1 p.     0 p.    118 000
# 392         8m²  1 p.     0 p.    109 000
# 524         9m²  2 p.     1 p.    770 000
# 572         9m²  1 p.     0 p.    110 000
# 589         9m²  1 p.     0 p.    110 000
# 639         7m²  1 p.     0 p.     90 000
# 694         8m²  1 p.     0 p.     95 000
# 701         8m²  1 p.     0 p.     78 000
# 718         9m²  1 p.     0 p.    132 500
# 760         7m²  1 p.     0 p.     55 000
# 832         7m²  1 p.     0 p.    127 500
# 871         5m²  1 p.     0 p.    600 000
# 878         7m²  1 p.     0 p.     88 000
# 880         8m²  1 p.     0 p.    150 000
# 885         5m²  1 p.     1 p.     85 150
# 988         6m²  1 p.     0 p.     70 000
# 1043        9m²  1 p.     0 p.    137 800
# ...

# %% [markdown]
# These kind of small apartments are usually called "Chambre de Bonne" and are usually at the last floor of a building. But these kinds of apartments are rare in Paris and therefore I think the best solution is to consider them as outliers.

# %%
df=df[~(df.m2<10)]

# %% [markdown]
# Now let's check the target variable Price_int ie the Price of the apartment in euros.

# %%
df.boxplot(column='Price_int')

# %% [markdown]
# It seems that there are a lot of outliers too. Let us explore these outliers.

# %%
print(df[df.Price_int>2100000].Loc_Paris.value_counts())
mean=df[df.Price_int>2100000].m2.mean()
print(f'Mean price is {mean}')
# Out:
# 16    29
# 7     22
# 6     22
# 8     17
# 14    11
# 17     9
# 13     7
# 5      5
# 3      3
# 4      2
# 18     1
# 15     1
# 9      1
# 2      1
# Name: Loc_Paris, dtype: int64
# Mean price is 137.06870229007635

# %% [markdown]
# These apartments are mostly situated in the expensive districts of Paris. And represents apartment of in average 140 m² which is very large for apartments in Paris. After looking on the net I found that the median area of an apartment in Paris is nearly 50m². I think the best idea is to drop these kind of unuasual apartments (ie treat them as outliers).

# %%
df= df[~(df.Price_int>2100000)]

# %% [markdown]
# I also want to explore the apartment that cost less than 100 000 euros, because I found that very weird.

# %%
df[df.Price_int<100000]
# Out:
#      Superficie Rooms Bedrooms    Price                         Location  \
# 2141       10m²  1 p.     0 p.  91 000   Paris 10 (75010)\r\nParis 10ème
# 2223       10m²  1 p.     0 p.  87 000         Paris 15 (75015)\r\nPARIS
# 2323       11m²  1 p.     0 p.  89 000     Paris 12 (75012)\r\nDaumesnil
# 2451       58m²  1 p.     0 p.  86 900    Paris 04 (75004)\r\nParis 4ème
# 2504       11m²  1 p.     0 p.  98 000         Paris 12 (75012)\r\nPARIS
#
#                                             description  Loc_Paris  m2  \
# 2141  Ref de l'annonce\r\n:5370\r\nEtage du bien\r\n...         10  10
# 2223  Ref de l'annonce\r\n:216239\r\nChauffage\r\n:I...         15  10
# 2323  Ref de l'annonce\r\n:30851149\r\nEtage du bien...         12  11
# 2451  Ref de l'annonce\r\n:227\r\nChauffage\r\n:Indi...          4  58
# 2504  Ref de l'annonce\r\n:216038\r\nEtage du bien\r...         12  11
#
#       building_floor  apartment_floor  nb_bath  Cellar balc_patio  \
# ...

# %%
# it seems that a 58m2 apartment is sold at 58000. That's very cheap, too cheap and very unusual. Let's drop it.
df.drop(2451,inplace=True)

# %% [markdown]
# ### Exploring the colinearity between the different features

# %% [markdown]
# We will use the method corr() to give us a hint of any linear relationship between features. A value close to 1 shows a strong positive correlation, and a value close to -1 means a strong negative correlation.

# %%
plt.figure(figsize=(12,9))
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# - Price and m2 are highly correlated. It is normal since we know that the price of an apartment is mostly due to its square feet.
# - What strikes me the most is that the number of floors of the building and the floor at which the apartment is situated is nearly not correlated at all with the Price. I expected very hight building to be less expensive than the others.
# - The number of bathrooms is also correlated with the price. This is normal since the number of bathrooms is representative of the quality ie the area of an apartmeent in general.
# - Presence or absence of a Cellar is also positively correlated with the Price. Does not strikes me.
# - It seems that the type of Heating does not have an impact on the Price.  I expected this. This is not something that real estate ask when they want to predict price of an apartment.
# - Also, what is weird is that apartments renovations or not are not very correlated with he Price of the House.
# - Same thing for presence or absence of a Parking.

# %%
sns.lmplot(x='m2',y='Price_int',data=df, hue='Parking')

# %% [markdown]
# ## Exploratory Data analysis of the categorical features

# %% [markdown]
# Looking at the correlation matrix, it is difficult to asses whether or not the renovation of a house increases or not its price. I will first have a look at this categorical feature.

# %%
sns.boxplot(x='Renovated',y='Price_int',data=df)

# %% [markdown]
# ### Number of occurences for each categorical features

# %%
for i in cat:
    plt.title(f' value count for {i}')
    sns.countplot(x=i,data=df,order=df[i].value_counts().index)
    plt.show()

# %% [markdown]
# - for the number of rooms: The higher the number of rooms the less number of apartments at sale. Seems normal since the average surface for an apartment in Paris is 46 m².
# - for the number of bedrooms: Same thing as the number of rooms.
# - for the number of floors of the building: mostly the number of floor of the building in Paris is between 9 and 3.
# - for the number of bathrooms: a lot of announces that do not specify the number of bathrooms. May be we should have a look at it.
# - for the number of apartments sold in each locations: districts with the more apartment availables are 16,15,18,20,17. And the districts with less apartments available are: the 1, 2,5,9,3,4
# - for the number of apartments which were renovated: a very small fraction of the apartments were renovated recently.

# %% [markdown]
# #### Investigating the feature number of rooms, bedrooms and bathrooms
# Normally the more rooms the higher the price. Let's check if it is the case

# %%
pd.pivot_table(df,index='Rooms',values='Price_int',).sort_values('Price_int')
# Out:
#           Price_int
# Rooms
# 1 p.   3.249513e+05
# 2 p.   5.417750e+05
# 3 p.   8.596821e+05
# 4 p.   1.108566e+06
# 5 p.   1.445101e+06
# 6 p.   1.661234e+06
# 7 p.   1.711143e+06

# %%
pd.pivot_table(df,index='Bedrooms',values='Price_int',).sort_values('Price_int')
# Out:
#              Price_int
# Bedrooms
# 0 p.      3.420751e+05
# 1 p.      5.845721e+05
# 2 p.      9.314711e+05
# 3 p.      1.252008e+06
# 6 p.      1.350000e+06
# 4 p.      1.534916e+06
# 5 p.      1.635143e+06

# %% [markdown]
# Perfect, it seems that our assumption is true. Yes, this is a really basic assumption but it proves the normality of the database or at least it proves that there is no problems in it.
# But what strikes me is that the average price for 6 bedrooms apartments is lower than the average price for 4 or 5 bedfooms apartments.
# After checking the number of occurences of 6 p apartments (only one occurence), this case might be an outlier. I will explore it.

# %%
df[df.Bedrooms=='6 p.']
# Out:
#     Superficie Rooms Bedrooms       Price                   Location  \
# 795      129m²  7 p.     6 p.  1 350 000   Paris 12 (75012)\r\nPARIS
#
#                                            description  Loc_Paris   m2  \
# 795  Ref de l'annonce\r\n:2280\r\nChauffage\r\n:Ind...         12  129
#
#      building_floor  apartment_floor  nb_bath  Cellar balc_patio  \
# 795               5                4        1       0          0
#
#                     Heating  Renovated  Parking  Heating_Central  \
# 795  Individuel, électrique          0        0                0
#
#      Heating_Individual  Price_int  Last_floor
# 795                   1    1350000           0

# %% [markdown]
# 7 piece for 6 bedrooms. What an unusual apartment. I will consider it as an outlier and drop it.

# %%
df.drop(795,inplace=True)

# %%
pd.pivot_table(df,index='nb_bath',values='Price_int',).sort_values('Price_int')
# Out:
#             Price_int
# nb_bath
# 0        6.115975e+05
# 1        8.799169e+05
# 10       8.990000e+05
# 2        1.564610e+06
# 4        1.600000e+06
# 3        1.656250e+06

# %% [markdown]
# Again, some apartments with more bathrooms cost less. That's weird. We need to explore it. After looking at the number of occurences it seems that there are very few apartments with mroe than 4 bathrooms. Seems normal. let us explore them.

# %%
df[df.nb_bath>=3]
# Out:
#      Superficie Rooms Bedrooms       Price  \
# 54         82m²  6 p.     3 p.    880 000
# 431       161m²  6 p.     4 p.  1 600 000
# 1756      142m²  6 p.     3 p.  1 995 000
# 1881      170m²  5 p.     3 p.  2 100 000
# 1913       80m²  4 p.     2 p.    899 000
# 2197       80m²  4 p.     2 p.    899 000
# 2319      115m²  4 p.     3 p.  1 650 000
#
#                                      Location  \
# 54             Paris 09 (75009)\r\nParis 9ème
# 431           Paris 15 (75015)\r\nParis 15ème
# 1756                Paris 16 (75116)\r\nParis
# 1881                Paris 16 (75016)\r\nParis
# 1913  Paris 10 (75010)|Château d'Eau - Lancry
# 2197   Paris 10 (75010)\r\nRépublique - Canal
# 2319              Paris 02 (75002)\r\nRéaumur
#
#                                             description  Loc_Paris   m2  \
# 54    Ref de l'annonce\r\n:6ff4a0\r\nChauffage\r\n:I...          9   82
# 431   Ref de l'annonce\r\n:VA1904-PARISIAN\r\nTerras...         15  161
# ...

# %% [markdown]
# Three outliers detected. 6p for 82 meters that is not possible. It might be an error. And 80 m2 for 10 bathrooms is not possible too, it might be an error. Let us drop them.

# %%
df.drop([54,1913,2197],inplace=True)

# %% [markdown]
# #### Exploring the feature nb_bath to determine why the number of bathrooms was not specified in a lot of cases.

# %%
df[df.nb_bath==0]
# Out:
#      Superficie Rooms Bedrooms       Price  \
# 2          32m²  1 p.     0 p.    375 000
# 4          29m²  1 p.     0 p.    346 500
# 6          28m²  1 p.     0 p.    355 000
# 12         25m²  2 p.     1 p.    385 000
# 14         23m²  1 p.     0 p.    313 500
# 18         40m²  2 p.     1 p.    400 000
# 20         51m²  3 p.     2 p.    575 000
# 24         60m²  3 p.     2 p.    830 000
# 26         39m²  2 p.     1 p.    446 000
# 30         42m²  2 p.     1 p.    610 000
# 31         51m²  2 p.     1 p.    638 600
# 37         74m²  4 p.     2 p.    930 000
# 38         31m²  1 p.     0 p.    387 000
# 44         21m²  1 p.     0 p.    310 000
# 48         32m²  2 p.     1 p.    371 000
# 51         63m²  3 p.     2 p.    978 000
# 58         44m²  2 p.     1 p.    595 000
# 64         32m²  1 p.     0 p.    282 000
# 66         50m²  3 p.     1 p.    635 000
# 69         38m²  2 p.     1 p.    349 000
# 70         95m²  3 p.     1 p.  1 390 000
# ...

# %% [markdown]
# After looking at logic_immo website, these apartments have a bathrooms, it was just not specified in their caracteristics. Therefor let's put a 1 instead of a 0.

# %%
df.nb_bath=df.nb_bath.apply(lambda x: 1 if x==0 else x)

# %%
df.nb_bath.value_counts()
# Out:
# 1    2139
# 2      73
# 3       3
# 4       1
# Name: nb_bath, dtype: int64

# %% [markdown]
# I am wondering why the Last floor feature is not correlated with the Price of the apartment. I thought that apartments at the last etage would be way more expensive due to the view and others factors. Let us explore it.

# %%
pd.pivot_table(df,index=['Last_floor','Rooms'],values='Price_int',).sort_values('Price_int')
# Out:
#                      Price_int
# Last_floor Rooms
# 1          1 p.   2.719803e+05
# 0          1 p.   3.453103e+05
# 1          2 p.   5.246397e+05
# 0          2 p.   5.455934e+05
#            3 p.   8.445297e+05
# 1          3 p.   9.653221e+05
# 0          4 p.   1.105113e+06
# 1          4 p.   1.157753e+06
#            5 p.   1.382692e+06
# 0          5 p.   1.454590e+06
# 1          7 p.   1.570000e+06
# 0          6 p.   1.674284e+06
# 1          6 p.   1.676154e+06
# 0          7 p.   1.811600e+06

# %% [markdown]
# On average this is not the case. I grouped by Rooms in the pivot table to avoid that "Chambre de bonne" affect to much the price of last floor apartments, since there are usually under at the last floor of the building.
# I do not understand why it seems that on average apartments on the last floor are less expensive. I will have a look at it on the Internet and try to understand this.

# %% [markdown]
# ### Checking if there is not abnormal number of rooms etc

# %%
df=df[~(df.Rooms<df.Bedrooms)]

# %% [markdown]
# ### Relationship between the price and the different categorical features

# %%
for i in cat:
    print(i)
    print(pd.pivot_table(df,index=i,values='Price_int',).sort_values('Price_int'))
    print('\n')
# Out:
# Rooms
#           Price_int
# Rooms
# 1 p.   3.230210e+05
# 2 p.   5.397143e+05
# 3 p.   8.596821e+05
# 4 p.   1.109813e+06
# 5 p.   1.445101e+06
# 6 p.   1.674703e+06
# 7 p.   1.771333e+06
#
#
# Bedrooms
#              Price_int
# Bedrooms
# 0 p.      3.420751e+05
# 1 p.      5.845721e+05
# 2 p.      9.338910e+05
# 3 p.      1.252826e+06
# 4 p.      1.534916e+06
# 5 p.      1.635143e+06
#
#
# building_floor
#                    Price_int
# building_floor
# 14              3.590812e+05
# 29              4.742500e+05
# 22              4.900000e+05
# 28              5.150000e+05
# 31              5.403750e+05
# 27              5.522500e+05
# 17              5.820000e+05
# 2               6.305383e+05
# 20              6.460000e+05
# 32              6.659286e+05
# 18              6.949070e+05
# 4               6.980636e+05
# 30              7.005036e+05
# 15              7.226000e+05
# 33              7.300000e+05
# 3               7.308781e+05
# 16              7.355833e+05
# ...

# %% [markdown]
# ## Normalization and Scaling

# %%
df.m2.hist()

# %%
df.Price_int.hist()

# %%
df.Price_int.skew()
# Out:
# 0.9855411638008159

# %%
#We will use the log transformation on the Price_int column.
df.Price_int=np.log(df.Price_int)
df.Price_int.skew()
# Out:
# -0.15488164370953003

# %%
df.Price_int.hist()

# %%
df.m2=np.log(df.m2)

# %%
df.m2.hist()

# %%
df.to_csv('final_data.csv',index=False)
